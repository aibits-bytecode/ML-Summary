# %% [markdown]
# # Welcome to Machine Learnings

# %% [markdown]
# ![Screenshot%202024-03-05%20at%2016.25.52.png](attachment:Screenshot%202024-03-05%20at%2016.25.52.png)

# %% [markdown]
# ![Screenshot%202024-03-05%20at%2016.46.30.png](attachment:Screenshot%202024-03-05%20at%2016.46.30.png)

# %% [markdown]
# ### Linear regression on single value
# ### y = mx + b

# %%
# # Creating the model
# from sklearn import linear_model
# reg = linear_model.LinearRegression()
# reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
# # Prediction
# reg.predict([[3300]])
# Out:
# /Users/chandimajayamina/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
# # This has y = mx+b equation
# print(reg.coef_)  # gives m values
# print(reg.intercept_) # gives b values
# Out:
# [135.78767123]
# 180616.43835616432

# %% [markdown]
# ### Linear regression on multiple variables

# %% [markdown]
# ![Screenshot%202024-03-05%20at%2020.28.57.png](attachment:Screenshot%202024-03-05%20at%2020.28.57.png)

# %%
# # Creating the model
# reg = linear_model.LinearRegression()
# reg.fit(df[['area','bedrooms','age']],df.price)
# Out:
# LinearRegression()

# %%
# reg.coef_ 
# # This gives coefficients(m1, m2, m3 etc)
# reg.intercept_
# # This gives the intercept(b value)
# Out:
# array([  112.06244194, 23388.88007794, -3231.71790863])

# %% [markdown]
# ## Gradient Descent

# %% [markdown]
# ![Screenshot%202024-03-23%20at%2012.23.55.png](attachment:Screenshot%202024-03-23%20at%2012.23.55.png)

# %% [markdown]
# ![Screenshot%202024-03-23%20at%2012.31.51.png](attachment:Screenshot%202024-03-23%20at%2012.31.51.png)

# %% [markdown]
# ![Screenshot%202024-03-23%20at%2012.45.39.png](attachment:Screenshot%202024-03-23%20at%2012.45.39.png)
